# %% [markdown]
# # Hello World Agent
#
# Objectives:
# 1. Understand agent state
# 2. Create simple node functions to process and update state
# 3. Set up basic LangGraph
# 4. Compile and invoke a LangGraph graph
# 5. Understand how data flows through a simple node

# %%
from typing import Dict, TypedDict
from langgraph.graph import StateGraph
#state graph is a framework that helps design and manage flow of tasks using a grpah

# %%
#Create the agent states - shared data structure that keeps track of information as your applicaiton runs
#has to be in the form of a dictionary type
class AgentState(TypedDict):
    message: str

#Now create the first node using standard python
#input is the state, output is the updated state
#Must include a doc string for the LLM/AI Agent to inform the purpose of the function
def greeting_node(state: AgentState) -> AgentState:
    """
    Simple node that adds a greeting message to the state.
    """

    state['message']
