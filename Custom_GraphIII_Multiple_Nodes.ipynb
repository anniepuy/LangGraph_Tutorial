# %%
from typing import TypedDict, List
from langgraph.graph import StateGraph

# %%
class AgentState(TypedDict):
    name: str
    age: int  # Changed to int to match the input
    skills: List[str]
    final: str  # Added the final field that's used in the nodes

# %%
def first_node(state: AgentState) -> AgentState:
    """
    This is the first node in our sequence.
    """
    state['final'] = f'Hi {state["name"]}'
    return state

def second_node(state: AgentState) -> AgentState:
    """This is the second node in our sequence"""
    state['final'] = state["final"] + f", you are {state['age']} years old"
    return state

def third_node(state: AgentState) -> AgentState:
    """This is the third node in our sequence"""
    # Format the skills list nicely
    skills_text = ", ".join(state["skills"])
    state['final'] = state["final"] + f". You are skilled at {skills_text}."
    return state

# %%
graph = StateGraph(AgentState)

graph.add_node("first_node", first_node)
graph.add_node("second_node", second_node)
graph.add_node("third_node", third_node)
graph.set_entry_point("first_node")
#Add an edge with start key and end key
graph.add_edge("first_node", "second_node")
graph.add_edge("second_node", "third_node")
graph.set_finish_point("third_node")

app = graph.compile()

# %%
result = app.invoke({"name": "Laura", "age": 33, "skills": ["Painting", "Drawing", "Programming"], "final": ""})
print(result)
print("\nFinal message:", result["final"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 result = app.invoke({"name": "Laura", "age": 33, "skills": ["Painting", "Drawing", "Programming"]})
#       2 print(result)
#
# File ~/Source/LangGraph_Tutorial/.venv/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2843, in Pregel.invoke(self, input, config, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, **kwargs)
#    2840 chunks: list[dict[str, Any] | Any] = []
#    2841 interrupts: list[Interrupt] = []
# -> 2843 for chunk in self.stream(
#    2844     input,
#    2845     config,
#    2846     stream_mode=["updates", "values"]
#    2847     if stream_mode == "values"
#    2848     else stream_mode,
#    2849     print_mode=print_mode,
#    2850     output_keys=output_keys,
#    2851     interrupt_before=interrupt_before,
#    2852     interrupt_after=interrupt_after,
#    2853     **kwargs,
#    2854 ):
#    2855     if stream_mode == "values":
#    2856         if len(chunk) == 2:
#
# File ~/Source/LangGraph_Tutorial/.venv/lib/python3.11/site-packages/langgraph/pregel/__init__.py:2533, in Pregel.stream(self, input, config, stream_mode, print_mode, output_keys, interrupt_before, interrupt_after, checkpoint_during, debug, subgraphs)
#    2531 for task in loop.match_cached_writes():
#    2532     loop.output_writes(task.id, task.writes, cached=True)
# -> 2533 for _ in runner.tick(
#    2534     [t for t in loop.tasks.values() if not t.writes],
#    2535     timeout=self.step_timeout,
#    2536     get_waiter=get_waiter,
#    2537     schedule_task=loop.accept_push,
#    2538 ):
#    2539     # emit output
#    2540     yield from _output(
#    2541         stream_mode, print_mode, subgraphs, stream.get, queue.Empty
#    2542     )
#    2543 loop.after_tick()
#
# Cell In[10], line 11, in second_node(state)
#       8 def second_node(state:AgentState) -> AgentState:
#       9     """This is the second node in our squence"""
# ---> 11     state['final'] = state["final"] + f" You are {state['age']} years old."
#      12     return state
#
# KeyError: 'final'
# During task with name 'second_node' and id 'bc48737c-5a4e-0b78-6f60-5eda7c9698d8'
